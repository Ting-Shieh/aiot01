# %% [markdown]
# 參考
# https://www.maxlist.xyz/2020/01/11/docker-flask/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### build
# docker build -t docker4ting/aiot-flask-test:v1 .
# ### push to docker hub
# docker push docker4ting/aiot-flask-test:v1

# %% [markdown]
# ![image.png](attachment:image.png)
